# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Maanz-AI/Desktop/pandas_tutorial/datas/B17.csv")

# %%
df.head()
# Out:
#                                   Location       Price      Area Bedrooms  \
# 0  MPCHS - Block C1, MPCHS - Multi Gardens   2.5 Crore   7 Marla        4
# 1   MPCHS - Block B, MPCHS - Multi Gardens   3.8 Crore  12 Marla        4
# 2   MPCHS - Block F, MPCHS - Multi Gardens  1.95 Crore   7 Marla        4
# 3  MPCHS - Block C1, MPCHS - Multi Gardens  1.75 Crore   5 Marla        3
# 4               Faisal Margalla City, B-17     2 Crore   7 Marla        6
#
#    Baths                                               Link
# 0      6  https://www.zameen.com//Property/mpchs_multi_g...
# 1      4  https://www.zameen.com//Property/mpchs_multi_g...
# 2      6  https://www.zameen.com//Property/mpchs_multi_g...
# 3      4  https://www.zameen.com//Property/mpchs_multi_g...
# 4      6  https://www.zameen.com//Property/b_17_faisal_m...

# %%
# checking name of the columns
df.columns
# Out:
# Index(['Location', 'Price', 'Area', 'Bedrooms', 'Baths', 'Link'], dtype='object')

# %%
# renaming columns like Price to Complete Price and similar Link to Complete Link
df.rename(columns={'Link':'Complete Link','Price':'Complete Price'},inplace=True)

# %%
df
# Out:
#                                     Location Complete Price       Area  \
# 0    MPCHS - Block C1, MPCHS - Multi Gardens      2.5 Crore    7 Marla
# 1     MPCHS - Block B, MPCHS - Multi Gardens      3.8 Crore   12 Marla
# 2     MPCHS - Block F, MPCHS - Multi Gardens     1.95 Crore    7 Marla
# 3    MPCHS - Block C1, MPCHS - Multi Gardens     1.75 Crore    5 Marla
# 4                 Faisal Margalla City, B-17        2 Crore    7 Marla
# ..                                       ...            ...        ...
# 170  MPCHS - Block C1, MPCHS - Multi Gardens      2.4 Crore  8.5 Marla
# 171                          B-17, Islamabad      1.2 Crore    4 Marla
# 172   MPCHS - Block C, MPCHS - Multi Gardens      6.6 Crore  1.2 Kanal
# 173   MPCHS - Block C, MPCHS - Multi Gardens      2.1 Crore    8 Marla
# 174                          B-17, Islamabad      2.9 Crore   10 Marla
#
#     Bedrooms  Baths                                      Complete Link
# ...

# %%
# checking columns name
df.columns
# Out:
# Index(['Location', 'Complete Price', 'Area', 'Bedrooms', 'Baths',
#        'Complete Link'],
#       dtype='object')

# %%
# another way to change columns name
new_columns=['loc','pri','are','bed','bat','lk']
df.columns=new_columns

# %%
df
# Out:
#                                          loc         pri        are bed  bat  \
# 0    MPCHS - Block C1, MPCHS - Multi Gardens   2.5 Crore    7 Marla   4    6
# 1     MPCHS - Block B, MPCHS - Multi Gardens   3.8 Crore   12 Marla   4    4
# 2     MPCHS - Block F, MPCHS - Multi Gardens  1.95 Crore    7 Marla   4    6
# 3    MPCHS - Block C1, MPCHS - Multi Gardens  1.75 Crore    5 Marla   3    4
# 4                 Faisal Margalla City, B-17     2 Crore    7 Marla   6    6
# ..                                       ...         ...        ...  ..  ...
# 170  MPCHS - Block C1, MPCHS - Multi Gardens   2.4 Crore  8.5 Marla   7    7
# 171                          B-17, Islamabad   1.2 Crore    4 Marla   3    3
# 172   MPCHS - Block C, MPCHS - Multi Gardens   6.6 Crore  1.2 Kanal   6    8
# 173   MPCHS - Block C, MPCHS - Multi Gardens   2.1 Crore    8 Marla   4    4
# 174                          B-17, Islamabad   2.9 Crore   10 Marla   8    8
#
# ...

# %%
# checking columns name
df.columns
# Out:
# Index(['loc', 'pri', 'are', 'bed', 'bat', 'lk'], dtype='object')

# %%
# another way of changing columns name
new_name=['LO','PR','AR','BE','BA','L K']
df=pd.read_csv("C:/Users/Maanz-AI/Desktop/pandas_tutorial/datas/B17.csv", header=0, names=new_name)

# %%
df
# Out:
#                                           LO          PR         AR BE  BA  \
# 0    MPCHS - Block C1, MPCHS - Multi Gardens   2.5 Crore    7 Marla  4   6
# 1     MPCHS - Block B, MPCHS - Multi Gardens   3.8 Crore   12 Marla  4   4
# 2     MPCHS - Block F, MPCHS - Multi Gardens  1.95 Crore    7 Marla  4   6
# 3    MPCHS - Block C1, MPCHS - Multi Gardens  1.75 Crore    5 Marla  3   4
# 4                 Faisal Margalla City, B-17     2 Crore    7 Marla  6   6
# ..                                       ...         ...        ... ..  ..
# 170  MPCHS - Block C1, MPCHS - Multi Gardens   2.4 Crore  8.5 Marla  7   7
# 171                          B-17, Islamabad   1.2 Crore    4 Marla  3   3
# 172   MPCHS - Block C, MPCHS - Multi Gardens   6.6 Crore  1.2 Kanal  6   8
# 173   MPCHS - Block C, MPCHS - Multi Gardens   2.1 Crore    8 Marla  4   4
# 174                          B-17, Islamabad   2.9 Crore   10 Marla  8   8
#
#                                                    L K
# ...

# %%
# checking columns name
df.columns
# Out:
# Index(['LO', 'PR', 'AR', 'BE', 'BA', 'L K'], dtype='object')

# %%
# removing space with in columns name by using str.replace() method 
df.columns=df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['LO', 'PR', 'AR', 'BE', 'BA', 'L_K'], dtype='object')
