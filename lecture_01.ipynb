# %%
# reading package
import pandas as pd

# %%
# opeing connection --file
df=pd.read_csv("C:/Users/Maanz-AI/Desktop/pandas_tutorial/datas/B17.csv")

# %%
# reading first 5 records
df.head()
# Out:
#                                   Location       Price      Area Bedrooms  \
# 0  MPCHS - Block C1, MPCHS - Multi Gardens   2.5 Crore   7 Marla        4
# 1   MPCHS - Block B, MPCHS - Multi Gardens   3.8 Crore  12 Marla        4
# 2   MPCHS - Block F, MPCHS - Multi Gardens  1.95 Crore   7 Marla        4
# 3  MPCHS - Block C1, MPCHS - Multi Gardens  1.75 Crore   5 Marla        3
# 4               Faisal Margalla City, B-17     2 Crore   7 Marla        6
#
#    Baths                                               Link
# 0      6  https://www.zameen.com//Property/mpchs_multi_g...
# 1      4  https://www.zameen.com//Property/mpchs_multi_g...
# 2      6  https://www.zameen.com//Property/mpchs_multi_g...
# 3      4  https://www.zameen.com//Property/mpchs_multi_g...
# 4      6  https://www.zameen.com//Property/b_17_faisal_m...

# %%
# reading last 5 records
df.tail()
# Out:
#                                     Location      Price       Area Bedrooms  \
# 170  MPCHS - Block C1, MPCHS - Multi Gardens  2.4 Crore  8.5 Marla        7
# 171                          B-17, Islamabad  1.2 Crore    4 Marla        3
# 172   MPCHS - Block C, MPCHS - Multi Gardens  6.6 Crore  1.2 Kanal        6
# 173   MPCHS - Block C, MPCHS - Multi Gardens  2.1 Crore    8 Marla        4
# 174                          B-17, Islamabad  2.9 Crore   10 Marla        8
#
#      Baths                                               Link
# 170      7  https://www.zameen.com//Property/mpchs_multi_g...
# 171      3  https://www.zameen.com//Property/islamabad_b_1...
# 172      8  https://www.zameen.com//Property/mpchs_multi_g...
# 173      4  https://www.zameen.com//Property/mpchs_multi_g...
# 174      8  https://www.zameen.com//Property/islamabad_b_1...

# %%
# reading ist 10 records --- can be customize
df.head(10)
# Out:
#                                             Location       Price       Area  \
# 0            MPCHS - Block C1, MPCHS - Multi Gardens   2.5 Crore    7 Marla
# 1             MPCHS - Block B, MPCHS - Multi Gardens   3.8 Crore   12 Marla
# 2             MPCHS - Block F, MPCHS - Multi Gardens  1.95 Crore    7 Marla
# 3            MPCHS - Block C1, MPCHS - Multi Gardens  1.75 Crore    5 Marla
# 4                         Faisal Margalla City, B-17     2 Crore    7 Marla
# 5             MPCHS - Block F, MPCHS - Multi Gardens  1.59 Crore    5 Marla
# 6                                    B-17, Islamabad     3 Crore   10 Marla
# 7  MPCHS - Block B Extension 1, MPCHS - Multi Gar...  2.55 Crore  7.8 Marla
# 8             MPCHS - Block B, MPCHS - Multi Gardens     5 Crore    1 Kanal
# 9                                    B-17, Islamabad   1.5 Crore    5 Marla
#
#   Bedrooms  Baths                                               Link
# ...

# %%
# reading last 10 records
df.tail(10)
# Out:
#                                     Location       Price       Area Bedrooms  \
# 165   MPCHS - Block C, MPCHS - Multi Gardens  2.55 Crore    7 Marla        6
# 166   MPCHS - Block B, MPCHS - Multi Gardens   5.3 Crore    1 Kanal        3
# 167                          B-17, Islamabad  1.98 Crore    7 Marla        4
# 168   MPCHS - Block E, MPCHS - Multi Gardens   2.3 Crore    8 Marla        4
# 169                          B-17, Islamabad  2.05 Crore    7 Marla        6
# 170  MPCHS - Block C1, MPCHS - Multi Gardens   2.4 Crore  8.5 Marla        7
# 171                          B-17, Islamabad   1.2 Crore    4 Marla        3
# 172   MPCHS - Block C, MPCHS - Multi Gardens   6.6 Crore  1.2 Kanal        6
# 173   MPCHS - Block C, MPCHS - Multi Gardens   2.1 Crore    8 Marla        4
# 174                          B-17, Islamabad   2.9 Crore   10 Marla        8
#
#      Baths                                               Link
# ...

# %%
# find shape like rows and columns
df.shape
# Out:
# (175, 6)

# %%
# number of rows
df.shape[0]
# Out:
# 175

# %%
# number of columns
df.shape[1]
# Out:
# 6

# %%
# culmns name
df.columns
# Out:
# Index(['Location', 'Price', 'Area', 'Bedrooms', 'Baths', 'Link'], dtype='object')

# %%
# removing headers
df2=pd.read_csv("C:/Users/Maanz-AI/Desktop/pandas_tutorial/datas/B17.csv", header=None)

# %%
df2
# Out:
#                                            0           1          2         3  \
# 0                                   Location       Price       Area  Bedrooms
# 1    MPCHS - Block C1, MPCHS - Multi Gardens   2.5 Crore    7 Marla         4
# 2     MPCHS - Block B, MPCHS - Multi Gardens   3.8 Crore   12 Marla         4
# 3     MPCHS - Block F, MPCHS - Multi Gardens  1.95 Crore    7 Marla         4
# 4    MPCHS - Block C1, MPCHS - Multi Gardens  1.75 Crore    5 Marla         3
# ..                                       ...         ...        ...       ...
# 171  MPCHS - Block C1, MPCHS - Multi Gardens   2.4 Crore  8.5 Marla         7
# 172                          B-17, Islamabad   1.2 Crore    4 Marla         3
# 173   MPCHS - Block C, MPCHS - Multi Gardens   6.6 Crore  1.2 Kanal         6
# 174   MPCHS - Block C, MPCHS - Multi Gardens   2.1 Crore    8 Marla         4
# 175                          B-17, Islamabad   2.9 Crore   10 Marla         8
#
# ...

# %%
# assigning new names to the columns
new_col_names=['L','P','A','Be','Ba']
df3=pd.read_csv("C:/Users/Maanz-AI/Desktop/pandas_tutorial/datas/B17.csv", header=0, names=new_col_names)

# %%
df3
# Out:
#                                                   L          P  A  Be  \
# MPCHS - Block C1, MPCHS - Multi Gardens   2.5 Crore    7 Marla  4   6
# MPCHS - Block B, MPCHS - Multi Gardens    3.8 Crore   12 Marla  4   4
# MPCHS - Block F, MPCHS - Multi Gardens   1.95 Crore    7 Marla  4   6
# MPCHS - Block C1, MPCHS - Multi Gardens  1.75 Crore    5 Marla  3   4
# Faisal Margalla City, B-17                  2 Crore    7 Marla  6   6
# ...                                             ...        ... ..  ..
# MPCHS - Block C1, MPCHS - Multi Gardens   2.4 Crore  8.5 Marla  7   7
# B-17, Islamabad                           1.2 Crore    4 Marla  3   3
# MPCHS - Block C, MPCHS - Multi Gardens    6.6 Crore  1.2 Kanal  6   8
# MPCHS - Block C, MPCHS - Multi Gardens    2.1 Crore    8 Marla  4   4
# B-17, Islamabad                           2.9 Crore   10 Marla  8   8
#
#                                                                                         Ba
# ...
